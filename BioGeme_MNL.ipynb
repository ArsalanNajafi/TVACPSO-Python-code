# %% [markdown]
# <a href="https://colab.research.google.com/github/ArsalanNajafi/TVACPSO-Python-code/blob/main/BioGeme_MNL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install biogeme pandas openpyxl

import pandas as pd
import biogeme.database as db
import biogeme.biogeme as bio
import biogeme.models as models
from biogeme.expressions import Beta, Variable
from google.colab import files

# Upload your data file
uploaded = files.upload()
file_name = list(uploaded.keys())[0]

# Load data
df = pd.read_excel(file_name)

# Create Biogeme database
database = db.Database('survey_db', df)

# Define variables
PLUG_IN_PAIRS = Variable('plug_in_pairs')
DAYS_PARTICIPATION = Variable('days_participation')
MIN_RANGE_KM = Variable('min_range_km')
REMUNERATION_SEK = Variable('remuneration_sek')
CHOICE = Variable('choice')

# Parameters to estimate
BETA_PLUG_IN = Beta('BETA_PLUG_IN', 0, None, None, 0)
BETA_DAYS = Beta('BETA_DAYS', 0, None, None, 0)
BETA_RANGE = Beta('BETA_RANGE', 0, None, None, 0)
BETA_REMUNERATION = Beta('BETA_REMUNERATION', 0, None, None, 0)

# Utility functions
V1 = BETA_PLUG_IN * PLUG_IN_PAIRS + BETA_DAYS * DAYS_PARTICIPATION + \
     BETA_RANGE * MIN_RANGE_KM + BETA_REMUNERATION * REMUNERATION_SEK
V2 = BETA_PLUG_IN * PLUG_IN_PAIRS + BETA_DAYS * DAYS_PARTICIPATION + \
     BETA_RANGE * MIN_RANGE_KM + BETA_REMUNERATION * REMUNERATION_SEK
V3 = 0  # Reference alternative

V = {1: V1, 2: V2, 3: V3}
av = {1: 1, 2: 1, 3: 1}

# Create and estimate model
logprob = models.loglogit(V, av, CHOICE)
biogeme = bio.BIOGEME(database, logprob)
biogeme.modelName = 'MNL_Colab'
results = biogeme.estimate()

# Show results
print(results.getEstimatedParameters())
print(f"\nRho-square: {1 - results.data.logLike/biogeme.calculateNullLoglikelihood(av)}")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 710.8/710.8 kB 11.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 484.7/484.7 kB 31.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.6/48.6 kB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 604.1/604.1 kB 33.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 11.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 57.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.4/85.4 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 85.0 MB/s eta 0:00:00
# ...
#   Created wheel for cythonbiogeme: filename=cythonbiogeme-1.0.4-cp311-cp311-linux_x86_64.whl size=6708186 sha256=8b40d82285f327d4d7ecbe17de9e54016f9d701e2822e6b3827df247d13935e3
# ...
